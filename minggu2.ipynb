# %%
import os
import pandas as pd
import networkx as ns
import numpy as np
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix, parallel_coordinates
import seaborn as sns

# %% [markdown]
# # 1

# %%
titanic = pd.read_csv('/Users/farrelmanazilin/Document/kuliah/data/Titanic.csv')
titanic
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp
# 0                              Braund, Mr. Owen Harris    male  22.0      1  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# #2

# %%
rows, cols = titanic.shape
print("Jumlah Baris: ", rows)
print("Jumlah Kolom: ", cols)
# Out:
# Jumlah Baris:  891
# Jumlah Kolom:  12

# %% [markdown]
# 3

# %%
features = titanic[["Name", "Sex", "Age", "Pclass", "Fare"]]
print(features)
# Out:
#                                                   Name     Sex   Age  Pclass
# 0                              Braund, Mr. Owen Harris    male  22.0       3  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0       1
# 2                               Heikkinen, Miss. Laina  female  26.0       3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0       1
# 4                             Allen, Mr. William Henry    male  35.0       3
# ..                                                 ...     ...   ...     ...
# 886                              Montvila, Rev. Juozas    male  27.0       2
# 887                       Graham, Miss. Margaret Edith  female  19.0       1
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN       3
# 889                              Behr, Mr. Karl Howell    male  26.0       1
# 890                                Dooley, Mr. Patrick    male  32.0       3
#
#         Fare
# 0     7.2500
# 1    71.2833
# ...

# %% [markdown]
# 4

# %%
Class = titanic["Survived"]
print(Class)
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
titanic['Relatives'] = titanic['SibSp'] + titanic['Parch']
print(titanic)
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp
# 0                              Braund, Mr. Owen Harris    male  22.0      1  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# 6

# %%
penumpang_Pclass = titanic["Pclass"].value_counts()
print(penumpang_Pclass)
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %% [markdown]
# 7

# %%
penumpang_Sex = titanic["Sex"].value_counts()
print(penumpang_Sex)
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %% [markdown]
# 8

# %%
survived_Pclass = titanic.groupby(["Pclass", "Survived"]).size()
print(survived_Pclass)
# Out:
# Pclass  Survived
# 1       0            80
#         1           136
# 2       0            97
#         1            87
# 3       0           372
#         1           119
# dtype: int64

# %% [markdown]
# 9

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.scatterplot(data=titanic, x=titanic.index, y='Sex', hue='Pclass')

plt.xlabel('Index Data')
plt.ylabel('Sex')
plt.title('Scatter plot: Pclass berdasarkan jenis kelamin')
plt.legend(title='Pclass')
plt.show()

# %% [markdown]
# 10

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.scatterplot(data=titanic, x=titanic.index, y='Age', hue='Pclass')

plt.xlabel('Index Data')
plt.ylabel('Age')
plt.title('Scatter plot: Pclass berdasarkan jenis kelamin')
plt.legend(title='Pclass')
plt.show()

# %%
k
