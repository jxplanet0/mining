# %%
import numpy as np
import pandas as pd

# %%
dataset = pd.read_csv('/Users/farrelmanazilin/Downloads/Dataset_M2/WestRoxbury.csv')
dataset
# Out:
#       TOTAL VALUE    TAX  LOT SQFT   YR BUILT  GROSS AREA   LIVING AREA
# 0            344.2  4330       9965      1880         2436         1352  \
# 1            412.6  5190       6590      1945         3108         1976
# 2            330.1  4152       7500      1890         2294         1371
# 3            498.6  6272      13773      1957         5032         2608
# 4            331.5  4170       5000      1910         2370         1438
# ...            ...   ...        ...       ...          ...          ...
# 5797         404.8  5092       6762      1938         2594         1714
# 5798         407.9  5131       9408      1950         2414         1333
# 5799         406.5  5113       7198      1987         2480         1674
# 5800         308.7  3883       6890      1946         2000         1000
# 5801         447.6  5630       7406      1950         2510         1600
#
#       FLOORS   ROOMS  BEDROOMS   FULL BATH  HALF BATH  KITCHEN  FIREPLACE
# ...

# %%
rows, cols = dataset.shape
print(rows,cols)
# Out:
# 5802 14

# %%
dataset.columns
# Out:
# Index(['TOTAL VALUE ', 'TAX', 'LOT SQFT ', 'YR BUILT', 'GROSS AREA ',
#        'LIVING AREA', 'FLOORS ', 'ROOMS', 'BEDROOMS ', 'FULL BATH',
#        'HALF BATH', 'KITCHEN', 'FIREPLACE', 'REMODEL'],
#       dtype='object')

# %%
dataset = dataset.rename(columns={"TOTAL VALUE " : "TOTAL_VALUE"})
dataset.columns
# Out:
# Index(['TOTAL_VALUE', 'TAX', 'LOT SQFT ', 'YR BUILT', 'GROSS AREA ',
#        'LIVING AREA', 'FLOORS ', 'ROOMS', 'BEDROOMS ', 'FULL BATH',
#        'HALF BATH', 'KITCHEN', 'FIREPLACE', 'REMODEL'],
#       dtype='object')

# %%
dataset.columns = [s.strip().replace(" ", "_") for s in dataset.columns]
dataset.columns
# Out:
# Index(['TOTAL_VALUE', 'TAX', 'LOT_SQFT', 'YR_BUILT', 'GROSS_AREA',
#        'LIVING_AREA', 'FLOORS', 'ROOMS', 'BEDROOMS', 'FULL_BATH', 'HALF_BATH',
#        'KITCHEN', 'FIREPLACE', 'REMODEL'],
#       dtype='object')

# %%
dataset.loc[0:5]
# Out:
#    TOTAL_VALUE   TAX  LOT_SQFT  YR_BUILT  GROSS_AREA  LIVING_AREA  FLOORS
# 0        344.2  4330      9965      1880        2436         1352     2.0  \
# 1        412.6  5190      6590      1945        3108         1976     2.0
# 2        330.1  4152      7500      1890        2294         1371     2.0
# 3        498.6  6272     13773      1957        5032         2608     1.0
# 4        331.5  4170      5000      1910        2370         1438     2.0
# 5        337.4  4244      5142      1950        2124         1060     1.0
#
#    ROOMS  BEDROOMS  FULL_BATH  HALF_BATH  KITCHEN  FIREPLACE REMODEL
# 0      6         3          1          1        1          0     NaN
# 1     10         4          2          1        1          0  Recent
# 2      8         4          1          1        1          0     NaN
# 3      9         5          1          1        1          1     NaN
# 4      7         3          2          0        1          0     NaN
# ...

# %%
dataset.iloc[0:5]
# Out:
#    TOTAL_VALUE   TAX  LOT_SQFT  YR_BUILT  GROSS_AREA  LIVING_AREA  FLOORS
# 0        344.2  4330      9965      1880        2436         1352     2.0  \
# 1        412.6  5190      6590      1945        3108         1976     2.0
# 2        330.1  4152      7500      1890        2294         1371     2.0
# 3        498.6  6272     13773      1957        5032         2608     1.0
# 4        331.5  4170      5000      1910        2370         1438     2.0
#
#    ROOMS  BEDROOMS  FULL_BATH  HALF_BATH  KITCHEN  FIREPLACE REMODEL
# 0      6         3          1          1        1          0     NaN
# 1     10         4          2          1        1          0  Recent
# 2      8         4          1          1        1          0     NaN
# 3      9         5          1          1        1          1     NaN
# 4      7         3          2          0        1          0     NaN

# %%
dataset["TAX"].iloc[0:10]
# Out:
# 0    4330
# 1    5190
# 2    4152
# 3    6272
# 4    4170
# 5    4244
# 6    4521
# 7    4030
# 8    4195
# 9    5150
# Name: TAX, dtype: int64

# %%
dataset.iloc[0:10]["TAX"]
# Out:
# 0    4330
# 1    5190
# 2    4152
# 3    6272
# 4    4170
# 5    4244
# 6    4521
# 7    4030
# 8    4195
# 9    5150
# Name: TAX, dtype: int64

# %%
dataset.iloc[5][0:7]
# Out:
# TOTAL_VALUE    337.4
# TAX             4244
# LOT_SQFT        5142
# YR_BUILT        1950
# GROSS_AREA      2124
# LIVING_AREA     1060
# FLOORS           1.0
# Name: 5, dtype: object

# %%
dataset.iloc[5, 0:7]
# Out:
# TOTAL_VALUE    337.4
# TAX             4244
# LOT_SQFT        5142
# YR_BUILT        1950
# GROSS_AREA      2124
# LIVING_AREA     1060
# FLOORS           1.0
# Name: 5, dtype: object

# %%
pd.concat((dataset.iloc[4:6, 5:8], dataset.iloc[10:15, 5:8]), axis=1)
# Out:
#     LIVING_AREA  FLOORS  ROOMS  LIVING_AREA  FLOORS  ROOMS
# 4        1438.0     2.0    7.0          NaN     NaN    NaN
# 5        1060.0     1.0    6.0          NaN     NaN    NaN
# 10          NaN     NaN    NaN       1485.0     1.5    6.0
# 11          NaN     NaN    NaN       1460.0     1.5    6.0
# 12          NaN     NaN    NaN       1290.0     2.0    6.0
# 13          NaN     NaN    NaN       2378.0     2.0    9.0
# 14          NaN     NaN    NaN       1272.0     1.5    6.0

# %%
print("Jumlah baris", len(dataset["TOTAL_VALUE"]))
print("Jumlah Mean:", dataset["TOTAL_VALUE"].mean())
# Out:
# Jumlah baris 5802
# Jumlah Mean: 392.6857149258877

# %%
dataset.describe()
# Out:
#        TOTAL_VALUE           TAX      LOT_SQFT     YR_BUILT   GROSS_AREA
# count  5802.000000   5802.000000   5802.000000  5802.000000  5802.000000  \
# mean    392.685715   4939.485867   6278.083764  1936.744916  2924.842123
# std      99.177414   1247.649118   2669.707974    35.989910   883.984726
# min     105.000000   1320.000000    997.000000     0.000000   821.000000
# 25%     325.125000   4089.500000   4772.000000  1920.000000  2347.000000
# 50%     375.900000   4728.000000   5683.000000  1935.000000  2700.000000
# 75%     438.775000   5519.500000   7022.250000  1955.000000  3239.000000
# max    1217.800000  15319.000000  46411.000000  2011.000000  8154.000000
#
#        LIVING_AREA       FLOORS        ROOMS     BEDROOMS    FULL_BATH
# count  5802.000000  5802.000000  5802.000000  5802.000000  5802.000000  \
# mean   1657.065322     1.683730     6.994829     3.230093     1.296794
# std     540.456726     0.444884     1.437657     0.846607     0.522040
# ...

# %%
dataset.sample(6)
# Out:
#       TOTAL_VALUE   TAX  LOT_SQFT  YR_BUILT  GROSS_AREA  LIVING_AREA  FLOORS
# 2030        426.3  5362      6180      1925        3300         1845     2.0  \
# 263         278.4  3502      4343      1959        2064          912     1.0
# 3122        418.1  5259      7591      1887        3064         1959     2.5
# 2151        417.9  5257      8116      1930        2568         1404     2.0
# 2712        422.3  5312      6719      1875        3797         2212     2.0
# 3339        456.2  5739      5405      1900        3419         2095     2.0
#
#       ROOMS  BEDROOMS  FULL_BATH  HALF_BATH  KITCHEN  FIREPLACE REMODEL
# 2030      9         4          1          1        1          1     Old
# 263       6         3          2          0        1          1     NaN
# 3122      7         4          1          1        1          1     NaN
# 2151      6         3          1          1        1          0     Old
# ...

# %%
weights = [0.0 if rooms > 10 else 0.01 for rooms in dataset.ROOMS]
dataset.sample(6, weights)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[143], line 2
#       1 weights = [0.0 if rooms > 10 else 0.01 for rooms in dataset.ROOMS]
# ----> 2 dataset.sample(6, weights)
#
# File ~/tomatopotato/lib/python3.10/site-packages/pandas/core/generic.py:5850, in NDFrame.sample(self, n, frac, replace, weights, random_state, axis, ignore_index)
#    5847 # Process random_state argument
#    5848 rs = common.random_state(random_state)
# -> 5850 size = sample.process_sampling_size(n, frac, replace)
#    5851 if size is None:
#    5852     assert frac is not None
#
# File ~/tomatopotato/lib/python3.10/site-packages/pandas/core/sample.py:93, in process_sampling_size(n, frac, replace)
#      91     n = 1
#      92 elif n is not None and frac is not None:
# ---> 93     raise ValueError("Please enter a value for `frac` OR `n`, not both")
#      94 elif n is not None:
# ...

# %%
dataset.dtypes
# Out:
# TOTAL_VALUE    float64
# TAX              int64
# LOT_SQFT         int64
# YR_BUILT         int64
# GROSS_AREA       int64
# LIVING_AREA      int64
# FLOORS         float64
# ROOMS            int64
# BEDROOMS         int64
# FULL_BATH        int64
# HALF_BATH        int64
# KITCHEN          int64
# FIREPLACE        int64
# REMODEL         object
# dtype: object

# %%
print(dataset.REMODEL.dtypes)
dataset.REMODEL = dataset.REMODEL.astype("category")
print(dataset.REMODEL.dtypes)
# Out:
# object
# category

# %%
print("Data Valid before:", dataset["BEDROOMS"].count())
missing = dataset.sample(6).index
dataset.loc[missing, "BEDROOMS"] = np.nan

print("Data Valid after:", dataset["BEDROOMS"].count())
# Out:
# Data Valid before: 5802
# Data Valid after: 5796

# %%
median_bed = dataset["BEDROOMS"].median()
print(median_bed)
# Out:
# 3.0

# %%
dataset_na = dataset.dropna()
print("Data Valid after:", dataset_na["BEDROOMS"].count())
# Out:
# Data Valid after: 1453

# %%
dataset.BEDROOMS = dataset.BEDROOMS.fillna(median_bed)
print("Data Valid after:", dataset["BEDROOMS"].count())
# Out:
# Data Valid after: 5802

# %%
dataset_na1 = dataset.dropna()
print("Data Valid after:", dataset_na1["BEDROOMS"].count())
# Out:
# Data Valid after: 1456
